# %% [markdown]
# # Configuración y Uso de Jupyter Notebook
#
# Este cuaderno contiene una guía completa para configurar y usar Jupyter Notebook en un entorno virtual desde VS Code.

# %% [markdown]
# ## 1. Entorno virtual y dependencias
#
# Crear y activar un entorno virtual es el primer paso. Esto asegura que tengas dependencias aisladas para tu proyecto.
#
# **Crear entorno virtual:**
# ```bash
# python -m venv venv
# ```
#
# **Activar en Unix/Linux/Mac:**
# ```bash
# source venv/bin/activate
# ```
#
# **Activar en Windows:**
# ```bash
# venv\Scripts\activate
# ```
#
# **Actualizar pip y herramientas base:**
# ```bash
# pip install --upgrade pip setuptools wheel
# ```

# %% [markdown]
# ## 2. Instalación de Jupyter
#
# Instala Jupyter Notebook o JupyterLab según tus necesidades.
#
# **Instalar Jupyter Notebook (más ligero):**
# ```bash
# pip install notebook
# ```
#
# **Instalar JupyterLab (más moderno y completo):**
# ```bash
# pip install jupyterlab
# ```
#
# **Verificar instalación:**
# ```bash
# jupyter --version
# ```

# %% [markdown]
# ## 3. Crear y lanzar un servidor Jupyter Notebook
#
# Una vez instalado, puedes iniciar el servidor de Jupyter.
#
# **Iniciar Jupyter Notebook:**
# ```bash
# jupyter notebook --no-browser --port=8888
# ```
#
# **Iniciar JupyterLab:**
# ```bash
# jupyter lab --port=8888
# ```
#
# **Parámetros útiles:**
# - `--no-browser`: No abre automáticamente el navegador
# - `--port=8888`: Puerto personalizado (por defecto 8888)
# - `--NotebookApp.token=''`: Sin token (solo para desarrollo local)
# - `--NotebookApp.password`: Contraseña (para producción)
#
# El servidor generará una URL con token similar a:
# ```
# http://localhost:8888/?token=abc123xyz...
# ```

# %% [markdown]
# ## 4. Crear y ejecutar celdas de Python
#
# En Jupyter, el trabajo se organiza en celdas. Aquí tienes ejemplos básicos.

# %%
# Ejemplo básico: Imprimir texto
print('Hola, Jupyter!')
print('Esta es mi primera celda de Python')

# %%
# Operaciones matemáticas
x = 10
y = 20
suma = x + y
print(f"La suma de {x} + {y} es {suma}")

# %% [markdown]
# **Atajos útiles:**
# - `Shift + Enter`: Ejecuta la celda y pasa a la siguiente
# - `Ctrl + Enter`: Ejecuta la celda sin cambiar
# - `Alt + Enter`: Ejecuta la celda e inserta una nueva debajo

# %% [markdown]
# ## 5. Magias de Jupyter
#
# Las magias son comandos especiales que amplían las funcionalidades de Jupyter.

# %%
# %%bash
# # Ejecutar comandos del shell
# echo "Esto es bash en Jupyter"
# ls -la

# %%
# %%timeit
# Medir el tiempo de ejecución
suma = 0
for i in range(1000):
    suma += i

# %% [markdown]
# ## 6. Configurar Kernels con ipykernel
#
# Para usar diferentes entornos virtuales en Jupyter, necesitas registrar kernels con `ipykernel`.
#
# **Instalar ipykernel:**
# ```bash
# pip install ipykernel
# ```
#
# **Registrar el entorno actual como kernel:**
# ```bash
# python -m ipykernel install --user --name=myenv --display-name 'Python (myenv)'
# ```
#
# **Listar kernels disponibles:**
# ```bash
# jupyter kernelspec list
# ```
#
# Luego puedes cambiar el kernel desde el menú superior en Jupyter Notebook/Lab.

# %% [markdown]
# ## 7. Integración con VS Code
#
# VS Code tiene soporte nativo para Jupyter Notebooks.
#
# **Pasos para usar Jupyter en VS Code:**
# 1. Abre un archivo `.ipynb` en VS Code
# 2. En la esquina superior derecha, selecciona el kernel
# 3. Elige el intérprete de Python de tu entorno virtual
# 4. Usa los botones "Run Cell" o "Run All" en la esquina de cada celda
# 5. Los resultados aparecerán directamente debajo de la celda
#
# **Atajos útiles en VS Code:**
# - `Ctrl + Shift + Enter` o `Cmd + Shift + Enter`: Ejecutar toda la celda
# - `Ctrl + Alt + Enter` o `Cmd + Alt + Enter`: Ejecutar toda la celda y celdas de abajo
# - Terminal integrada para ejecutar comandos shell relacionados

# %% [markdown]
# ## 8. Extensiones útiles para Jupyter
#
# **Extensiones recomendadas:**
#
# Para Jupyter Notebook Classic:
# ```bash
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# ```
#
# Extensiones populares:
# - **Table of Contents**: Índice automático de secciones
# - **Variable Inspector**: Inspecciona variables en tiempo real
# - **Spellchecker**: Corrector ortográfico
# - **ExecuteTime**: Muestra el tiempo de ejecución
#
# Para JupyterLab, muchas extensiones vienen por defecto o se instalan con:
# ```bash
# jupyter labextension install @jupyter-widgets/jupyterlab-manager
# ```

# %% [markdown]
# ## 9. Guardar, exportar y convertir notebooks
#
# Jupyter permite exportar cuadernos en múltiples formatos usando `nbconvert`.
#
# **Instalar nbconvert (viene con Jupyter):**
# ```bash
# pip install nbconvert
# ```
#
# **Exportar a HTML:**
# ```bash
# jupyter nbconvert --to html notebook.ipynb
# ```
#
# **Exportar a PDF:**
# ```bash
# jupyter nbconvert --to pdf notebook.ipynb
# ```
#
# **Exportar a script Python:**
# ```bash
# jupyter nbconvert --to script notebook.ipynb
# ```
#
# **Ejecutar y guardar resultados:**
# ```bash
# jupyter nbconvert --to notebook --execute --inplace notebook.ipynb
# ```
#
# **Con timeout para notebooks largos:**
# ```bash
# jupyter nbconvert --to notebook --execute --ExecutePreprocessor.timeout=600 --inplace notebook.ipynb
# ```

# %% [markdown]
# ## 10. Automatizar con scripts y tests
#
# Los notebooks pueden ejecutarse en pipelines CI/CD y probarse automáticamente.
#
# **Usar nbval para validar notebooks:**
# ```bash
# pip install nbval
# pytest --nbval notebook.ipynb
# ```
#
# **Ejecutar en un pipeline CI (ejemplo GitHub Actions):**
# ```yaml
# - name: Execute notebooks
#   run: |
#     jupyter nbconvert --to notebook --execute \
#     --ExecutePreprocessor.timeout=600 \
#     --inplace notebook.ipynb
# ```
#
# **Validar salidas esperadas:**
# ```bash
# nbval notebook.ipynb --current-kernel
# ```
#
# Esta es una excelente forma de garantizar que tus análisis y documentos estén siempre actualizados.

# %% [markdown]
# ## 11. Solución de problemas comunes
#
# **Problema: El kernel no responde**
# - Solución: Reinicia el kernel desde el menú (Kernel > Restart)
# - Si persiste, reinstala ipykernel: `pip install --force-reinstall ipykernel`
#
# **Problema: Puerto en uso (Port already in use)**
# - Solución: Usa otro puerto: `jupyter notebook --port=8889`
# - O termina el proceso: `lsof -i :8888` y luego `kill -9 PID`
#
# **Problema: Token o autenticación fallida**
# - Verifica el token en la URL que generó Jupyter
# - Copia-pega la URL completa con el token
#
# **Problema: Entorno virtual no reconocido**
# - Asegúrate de activar el venv: `source venv/bin/activate`
# - Verifica la ruta de Python: `which python`
#
# **Limpiar cache y runtimes:**
# ```bash
# rm -rf ~/.local/share/jupyter/runtime
# jupyter --path
# ```
#
# **Diagnóstico completo:**
# ```bash
# jupyter troubleshoot
# ```

# %% [markdown]
# ## 12. Resumen rápido - Comandos esenciales
#
# ```bash
# # Crear y activar entorno virtual
# python3 -m venv venv
# source venv/bin/activate  # En Unix/Linux/Mac
#
# # Instalar dependencias
# pip install --upgrade pip setuptools wheel
# pip install jupyter notebook ipykernel
#
# # Registrar kernel
# python -m ipykernel install --user --name=myproject
#
# # Iniciar Jupyter
# jupyter notebook --no-browser --port=8888
# # O usar JupyterLab:
# jupyter lab
#
# # Exportar notebook a HTML
# jupyter nbconvert --to html notebook.ipynb
#
# # Ejecutar y guardar
# jupyter nbconvert --to notebook --execute --inplace notebook.ipynb
# ```
#
# ¡Ahora estás listo para usar Jupyter Notebook! 🚀
